# %%
def get_successors(state):
    moves = [(-1, 0), (1, 0), (0, -1), (0, 1)]
    successors = []
    
    blank_r, blank_c = -1, -1
    for r in range(3):
        for c in range(3):
            if state[r][c] == 0:
                blank_r, blank_c = r, c
                break
                
    for dr, dc in moves:
        new_r = blank_r + dr
        new_c = blank_c + dc
        if 0 <= new_r < 3 and 0 <= new_c < 3:
            new_state = [list(row) for row in state]
            new_state[blank_r][blank_c] = new_state[new_r][new_c]
            new_state[new_r][new_c] = 0
            successors.append(tuple(tuple(row) for row in new_state))
    return successors

def run_dfs(start, goal):
    frontier = [(start, [start])]
    explored = set()
    expansion_sequence = []
    
    while len(frontier) > 0:
        current_state, path = frontier.pop()
        
        if current_state in explored:
            continue
            
        expansion_sequence.append(current_state)
        explored.add(current_state)
        
        if current_state == goal:
            return expansion_sequence, path, len(path) - 1
            
        for neighbor in reversed(get_successors(current_state)):
            if neighbor not in explored:
                frontier.append((neighbor, path + [neighbor]))
                
    return None, None, None

initial_state = ((1, 2, 3), (4, 0, 6), (7, 5, 8))
goal_state = ((1, 2, 3), (4, 5, 6), (7, 8, 0))

exp_seq, sol_path, cost = run_dfs(initial_state, goal_state)

print("DFS")
print("Sequence of Node Expansions:", len(exp_seq))
print("Total Path Cost:", cost)
print("\nSolution Path:")
for index, grid in enumerate(sol_path):
    print(f"Step {index}:")
    for row in grid:
        print(row)
    print()
# Out:
# DFS
# Sequence of Node Expansions: 31
# Total Path Cost: 30
#
# Solution Path:
# Step 0:
# (1, 2, 3)
# (4, 0, 6)
# (7, 5, 8)
#
# Step 1:
# (1, 0, 3)
# (4, 2, 6)
# (7, 5, 8)
#
# Step 2:
# (0, 1, 3)
# (4, 2, 6)
# (7, 5, 8)
#
# Step 3:
# (4, 1, 3)
# (0, 2, 6)
# (7, 5, 8)
#
# Step 4:
# (4, 1, 3)
# (7, 2, 6)
# (0, 5, 8)
#
# Step 5:
# (4, 1, 3)
# (7, 2, 6)
# (5, 0, 8)
#
# Step 6:
# (4, 1, 3)
# (7, 0, 6)
# (5, 2, 8)
#
# Step 7:
# (4, 0, 3)
# (7, 1, 6)
# (5, 2, 8)
#
# Step 8:
# (0, 4, 3)
# (7, 1, 6)
# (5, 2, 8)
#
# Step 9:
# (7, 4, 3)
# (0, 1, 6)
# (5, 2, 8)
#
# Step 10:
# (7, 4, 3)
# (5, 1, 6)
# (0, 2, 8)
#
# Step 11:
# (7, 4, 3)
# (5, 1, 6)
# (2, 0, 8)
#
# Step 12:
# (7, 4, 3)
# (5, 0, 6)
# (2, 1, 8)
#
# Step 13:
# (7, 0, 3)
# (5, 4, 6)
# (2, 1, 8)
#
# Step 14:
# (0, 7, 3)
# (5, 4, 6)
# (2, 1, 8)
#
# Step 15:
# (5, 7, 3)
# (0, 4, 6)
# (2, 1, 8)
#
# Step 16:
# (5, 7, 3)
# (2, 4, 6)
# (0, 1, 8)
#
# Step 17:
# (5, 7, 3)
# (2, 4, 6)
# (1, 0, 8)
#
# Step 18:
# (5, 7, 3)
# (2, 0, 6)
# (1, 4, 8)
#
# Step 19:
# (5, 0, 3)
# (2, 7, 6)
# (1, 4, 8)
#
# Step 20:
# (0, 5, 3)
# (2, 7, 6)
# (1, 4, 8)
#
# Step 21:
# (2, 5, 3)
# (0, 7, 6)
# (1, 4, 8)
#
# Step 22:
# (2, 5, 3)
# (1, 7, 6)
# (0, 4, 8)
#
# Step 23:
# (2, 5, 3)
# (1, 7, 6)
# (4, 0, 8)
#
# Step 24:
# (2, 5, 3)
# (1, 0, 6)
# (4, 7, 8)
#
# Step 25:
# (2, 0, 3)
# (1, 5, 6)
# (4, 7, 8)
#
# Step 26:
# (0, 2, 3)
# (1, 5, 6)
# (4, 7, 8)
#
# Step 27:
# (1, 2, 3)
# (0, 5, 6)
# (4, 7, 8)
#
# Step 28:
# (1, 2, 3)
# (4, 5, 6)
# (0, 7, 8)
#
# Step 29:
# (1, 2, 3)
# (4, 5, 6)
# (7, 0, 8)
#
# Step 30:
# (1, 2, 3)
# (4, 5, 6)
# (7, 8, 0)
